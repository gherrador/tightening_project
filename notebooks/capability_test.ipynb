# %%
from tightening_project.data.loader import build_capability_v1_core_for_month
from tightening_project.paths import LAKE_ROOT
import pandas as pd

outs = build_capability_v1_core_for_month(2026, 1, baseline_months=12, force=True)
print(outs)

cap = pd.read_parquet(
    LAKE_ROOT / "gold/capability/tier=core/baseline_window=12m/asof=2026-01/part-0000.parquet"
)
cap.sort_values("Cpk").head(10)
# Out:
# C:\Users\neri.herrador\Desktop\analisis\analisis\tightening_project\src\tightening_project\data\cleaning\helpers.py:61: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[dt_col] = pd.to_datetime(df[dt_col], utc=True, errors="coerce")
# C:\Users\neri.herrador\Desktop\analisis\analisis\tightening_project\src\tightening_project\data\loader.py:93: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   x["month"] = x[time_col].dt.to_period("M")
# {'capability': WindowsPath('C:/Users/neri.herrador/Desktop/analisis/analisis/tightening_project/data/lake/gold/capability/tier=core/baseline_window=12m/asof=2026-01/part-0000.parquet'), 'meta': WindowsPath('C:/Users/neri.herrador/Desktop/analisis/analisis/tightening_project/data/lake/gold/_meta/tier=core/asof=2026-01/gold_build_meta.json')}
# ...

# %%
cap.describe()
# Out:
#                 STEP_ID             N          n_mr       mean  std_overall  \
# count              76.0     76.000000     76.000000  76.000000    76.000000
# mean   617683966.789474   6233.855263   6232.855263  24.086073     2.043635
# std     314326298.08737   5879.576043   5879.576043  24.175735     2.816700
# min         112351201.0    620.000000    619.000000   0.399224     0.005548
# 25%         112364173.5   2164.750000   2163.750000   6.996553     0.117149
# 50%         811235256.0   4129.500000   4128.500000  14.017153     0.459507
# 75%         811235623.5   8865.750000   8864.750000  30.705163     2.067457
# max         811236481.0  29916.000000  29915.000000  82.850362    10.001328
#
#            mrbar  sigma_within        lsl        usl   tol_span         Pp  \
# count  76.000000     76.000000  76.000000  76.000000  76.000000  76.000000
# mean    1.109468      0.983571  23.028947  25.851316   2.822368   0.900100
# ...

# %%
import pandas as pd
from tightening_project.data.loader import build_silver_auto
df_base = pd.read_parquet(build_silver_auto())
df_step = df_base[df_base["STEP_ID"] == 811235531]
df_step["month"] = df_step["DateTime"].dt.to_period("M")

monthly = (
    df_step.groupby("month")["FinalTorque"]
    .agg(["count", "mean", "std"])
)

monthly
# Out:
# C:\Users\neri.herrador\AppData\Local\Temp\ipykernel_2296\577928173.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_step["month"] = df_step["DateTime"].dt.to_period("M")
# C:\Users\neri.herrador\AppData\Local\Temp\ipykernel_2296\577928173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_step["month"] = df_step["DateTime"].dt.to_period("M")
#          count       mean       std
# month
# 2026-01     78  44.265256  7.777522
